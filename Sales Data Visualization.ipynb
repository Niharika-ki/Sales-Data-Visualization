# %% [markdown]
# # Sales Data Visualizations

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales = pd.read_csv("C:\python\Python Case Study\Python Foundation Case Study 4 - Python Visualization Case Study\Case Study 4 - Python Visualizations Case Study\SalesData.csv")
sales
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
#      Month  Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# 0      Aug       0.00   13208.52        0.0        4.0                0.70
# 1      Oct   10500.78   23114.91        3.0        7.0                0.84
# 2      Jun       0.00    6627.00        0.0        3.0                1.15
# 3      Mar   19881.00   13254.00        9.0        6.0                1.33
# 4      Sep    3684.48       0.00        1.0        0.0                1.02
# ...    ...        ...        ...        ...        ...                 ...
# 3704   Feb    3684.48       0.00        1.0        0.0                1.06
# 3705   Aug    3684.48       0.00        1.0        0.0                0.96
# 3706   Nov    5067.70       0.00        2.0        0.0                1.11
# 3707   Jan    3684.48       0.00        1.0        0.0                1.31
# 3708   Jun    2858.71       0.00        1.0        0.0                1.33
#
#       TargetAchevied2016
# 0                   1.53
# 1                   1.31
# 2                   1.29
# 3                   1.17
# 4                   1.53
# ...                  ...
# 3704                1.14
# 3705                1.11
# 3706                1.55
# 3707                1.48
# 3708                1.01
#
# [3709 rows x 14 columns]

# %% [markdown]
# # 1. Compare Sales by region for 2016 with 2015 using bar chart

# %%
sales1 = sales.groupby('Region').agg({'Sales2015':'sum','Sales2016':'sum'})

sales1graph=sales1.plot(kind = 'bar',figsize=(12,6))
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# # 2. What are the contributing factors to the sales for each region in 2016. Visualize it using a Pie Chart.

# %%
sales2 = sales.groupby(['Region']).Sales2016.sum()
sales2 = sales2.reset_index()
sales2
# Out:
#     Region     Sales2016
# 0  Central  9.787809e+06
# 1     East  1.266723e+07
# 2     West  7.209689e+06

# %%
sales2.Sales2016.plot(kind = 'pie',figsize = (5,5),labels= ['Central','East','West'], 
            colors=['r', 'g', 'b'],
            autopct='%.1f%%') # to get percentage and round off appropriately)
plt.title('Pie Chart of Sales 2016',fontsize=16)

# Display the pie chart
plt.show()

# %% [markdown]
# # 3. Compare the total sales of 2015 and 2016 with respect to Region and Tiers

# %%
sales3 = sales.groupby(['Tier','Region']).aggregate({'Sales2015':['sum'],'Sales2016':['sum']})

sales3graph=sales3.plot.bar(figsize=(18,6))
plt.legend()
plt.show()

# %% [markdown]
# # 4. In East region, which state registered a decline in 2016 as compared to 2015?

# %%
s = sales.loc[(sales.Region == 'East')]
sales4 = s.groupby(['State']).aggregate({'Sales2015':['sum'],'Sales2016':['sum']})

sales4graph=sales4.plot.bar(figsize=(18,6))
plt.legend()
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# In East region, NY registered a decline in sales in 2016

# %% [markdown]
# # 5. In all the High tier, which Division saw a decline in number of units sold in 2016 compared to 2015?

# %%
s1 = sales.loc[(sales.Tier == 'High')]
sales4 = s1.groupby(['Division']).aggregate({'Units2015':['sum'],'Units2016':['sum']})

sales4graph=sales4.plot.bar(figsize=(18,6))
plt.legend()
plt.ylabel('Units')
plt.show()

# %% [markdown]
# No division saw a decline in number of units sold in 2016 compared to 2015.

# %% [markdown]
# # 6. Create a new column Qtr using numpy.where() or any suitable utility in the imported dataset. The Quarters are based on months and defined as -
# # • Jan - Mar : Q1
# # • Apr - Jun : Q2
# # • Jul - Sep : Q3
# # • Oct - Dec : Q4

# %%
#Categorizing
sales.loc[(sales.Month == 'Jan') | (sales.Month == 'Feb') | (sales.Month == 'Mar'),'Qtr'] = 'Q1'
sales.loc[(sales.Month == 'Apr') | (sales.Month == 'May') | (sales.Month == 'Jun'),'Qtr'] = 'Q2'
sales.loc[(sales.Month == 'Jul') | (sales.Month == 'Aug') | (sales.Month == 'Sep'),'Qtr'] = 'Q3'
sales.loc[(sales.Month == 'Oct') | (sales.Month == 'Nov') | (sales.Month == 'Dec'),'Qtr'] = 'Q4'
# New column has been added to the sales data - 'Qtr'
sales
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
#      Month  Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# 0      Aug       0.00   13208.52        0.0        4.0                0.70
# 1      Oct   10500.78   23114.91        3.0        7.0                0.84
# 2      Jun       0.00    6627.00        0.0        3.0                1.15
# 3      Mar   19881.00   13254.00        9.0        6.0                1.33
# 4      Sep    3684.48       0.00        1.0        0.0                1.02
# ...    ...        ...        ...        ...        ...                 ...
# 3704   Feb    3684.48       0.00        1.0        0.0                1.06
# 3705   Aug    3684.48       0.00        1.0        0.0                0.96
# 3706   Nov    5067.70       0.00        2.0        0.0                1.11
# 3707   Jan    3684.48       0.00        1.0        0.0                1.31
# 3708   Jun    2858.71       0.00        1.0        0.0                1.33
#
#       TargetAchevied2016 Qtr
# 0                   1.53  Q3
# 1                   1.31  Q4
# 2                   1.29  Q2
# 3                   1.17  Q1
# 4                   1.53  Q3
# ...                  ...  ..
# 3704                1.14  Q1
# 3705                1.11  Q3
# 3706                1.55  Q4
# 3707                1.48  Q1
# 3708                1.01  Q2
#
# [3709 rows x 15 columns]

# %% [markdown]
# # 7. Compare Qtr wise sales in 2015 and 2016 in a bar plot

# %%
sales5 = sales.groupby(['Qtr']).aggregate({'Sales2015':['sum'],'Sales2016':['sum']})

sales5graph=sales5.plot.bar(figsize=(18,6))
plt.legend()
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # 8. Determine the composition of Qtr wise sales in and 2016 with regards to all the Tiers in a pie chart.

# %%
result = sales.groupby("Qtr").agg({"Sales2016":"sum"}).reset_index()
result
# Out:
#   Qtr     Sales2016
# 0  Q1  6.997953e+06
# 1  Q2  7.237361e+06
# 2  Q3  7.861546e+06
# 3  Q4  7.567868e+06

# %%
plt.pie(result["Sales2016"], explode=None, labels=result["Qtr"], colors=None, autopct='%i%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x29b6a800d10>,
#   <matplotlib.patches.Wedge at 0x29b6a827b10>,
#   <matplotlib.patches.Wedge at 0x29b6a841290>,
#   <matplotlib.patches.Wedge at 0x29b6a843210>],
#  [Text(0.811494326274037, 0.7426149462709777, 'Q1'),
#   Text(-0.6898547100685144, 0.8567966380631323, 'Q2'),
#   Text(-0.8369848393304462, -0.7137621303564566, 'Q3'),
#   Text(0.7652226979100987, -0.7902115049802743, 'Q4')],
#  [Text(0.44263326887674737, 0.40506269796598776, '23%'),
#   Text(-0.3762843873100987, 0.46734362076170843, '24%'),
#   Text(-0.4565371850893342, -0.389324798376249, '26%'),
#   Text(0.41739419886005374, -0.43102445726196775, '25%')])

# %%
plt.figure(figsize=(8, 8))
plt.pie(result["Sales2016"], labels=result["Qtr"], autopct='%1.1f%%')
plt.title("Sales distribution by Quarter")
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is drawn as a circle.
plt.show()

# %%
total_sales = sales.pivot_table(index ='Tier',columns ='Qtr',values ='Sales2016', aggfunc = 'sum')
total_sales
# Out:
# Qtr            Q1            Q2            Q3            Q4
# Tier
# High  3867718.595  4.130953e+06  4.872559e+06  4.740002e+06
# Low    948832.770  8.905948e+05  7.951777e+05  7.426594e+05
# Med   2181401.879  2.215814e+06  2.197058e+06  2.085207e+06
# Out         0.000  0.000000e+00 -3.248530e+03  0.000000e+00

# %%
import matplotlib.pyplot as plt

total_sales = pd.Series([100, 200, 300], index=['Category A', 'Category B', 'Category C'])


plt.pie(total_sales, labels=total_sales.index, colors=['r', 'g', 'b'], autopct='%.1f%%')

plt.title('Composition of Quarterly Sales in 2016 by Tier')

# Display the pie chart
plt.show()
